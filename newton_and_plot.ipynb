# %% [markdown]
# <a href="https://colab.research.google.com/github/yosuketorizuka/newton_and_plot/blob/main/newton_and_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.optimize import newton

# %matplotlib inline

def my_function(x):
  return x ** 2 -  x - 506

x = np.arange(-30, 30)
plt.figure(figsize = (20, 6))
plt.plot(x, my_function(x))
plt.grid(True)

print(newton(my_function, 365))
# Out:
# 23.0
